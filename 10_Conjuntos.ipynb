# %%
mi_conjunto = {"A", "B", "C", "D"}

conjunto_vacio = set()

lista_base = [10, 20, 30, 40, 20]
conjunto_numeros = set(lista_base)
print(conjunto_numeros)
# Out:
# {40, 10, 20, 30}

# %%
conjunto_uno = {"Hugo", "Paco", "Luis"}
conjunto_dos= {"Britni", "Llojan", "Luis"}
print("CONJUNTOS")
print(conjunto_uno)
print(conjunto_dos)
print()

print("UNIÓN")
print(conjunto_uno | conjunto_dos)
print()

print("INTERSECCIÓN")
print(conjunto_uno & conjunto_dos)
print()

print("DIFERENCIA")
print(conjunto_uno - conjunto_dos)
print()

print("DIFERENCIA SIMËTRICA")
print(conjunto_uno ^ conjunto_dos)
# Out:
# CONJUNTOS
# {'Paco', 'Luis', 'Hugo'}
# {'Luis', 'Britni', 'Llojan'}
#
# UNIÓN
# {'Britni', 'Luis', 'Llojan', 'Paco', 'Hugo'}
#
# INTERSECCIÓN
# {'Luis'}
#
# DIFERENCIA
# {'Paco', 'Hugo'}
#
# DIFERENCIA SIMËTRICA
# {'Britni', 'Llojan', 'Paco', 'Hugo'}

# %%
conjunto_tres = {"Paco", "Luis"}

print(conjunto_tres <= conjunto_uno)
# Out:
# True

# %%
import random

valores = [random.randrange(1, 6) for valor in range(100)]
print(valores)

diferentes = set(valores)
print()
print(diferentes)
# Out:
# [3, 3, 2, 2, 4, 4, 3, 5, 3, 2, 1, 2, 5, 4, 5, 4, 3, 2, 3, 1, 5, 4, 5, 4, 5, 2, 5, 5, 3, 5, 2, 4, 5, 5, 4, 5, 1, 2, 1, 5, 5, 4, 4, 4, 5, 5, 4, 4, 5, 4, 5, 2, 4, 2, 4, 2, 5, 4, 4, 5, 2, 5, 4, 1, 5, 1, 3, 4, 2, 3, 5, 5, 2, 1, 5, 4, 2, 5, 5, 2, 1, 3, 1, 4, 5, 1, 4, 2, 3, 2, 4, 4, 2, 5, 2, 5, 1, 5, 5, 1]
#
# {1, 2, 3, 4, 5}

# %%
conjunto = set()

conjunto.add(10)
print(conjunto)

conjunto.update([20, 30, 40])
print(conjunto)
# Out:
# {10}
# {40, 10, 20, 30}

# %%
conjunto = {10, 20, 30, 40}
print(conjunto)

conjunto.remove(20)
print(conjunto)

conjunto.discard(100)
print(conjunto)
# Out:
# {40, 10, 20, 30}
# {40, 10, 30}
# {40, 10, 30}
