# %%
import time

seg = int(input("Cantidad de segundos a esperar: "))
time.sleep(seg)
print(f"Han pasado {seg} segundo.")
# Out:
# Cantidad de segundos a esperar: 5
# Han pasado 5 segundo.

# %%
hrInicial = time.time()

for termino in range(10):
  time.sleep(seg)

print(f"Proceso simulado terminado.")
dur = time.time() - hrInicial
print(f"Duración: {dur:.2f} segundos.")
# Out:
# Proceso simulado terminado.
# Duración: 50.00 segundos.
