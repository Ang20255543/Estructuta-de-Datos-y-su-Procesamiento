# %% [markdown]
# <a href="https://colab.research.google.com/github/Ang20255543/Estructuta-de-Datos-y-su-Procesamiento/blob/main/16_ExcelConPyton.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import datetime
import openpyxl
import random

libro = openpyxl.Workbook()
hoja = libro["Sheet"]
hoja.title = "Primera"

hoja["B1"].value ="Listado de numeros"

for renglon in range (2, 12):
  hoja.cell(row=renglon, column=2).value = random.randrange(100)

hoja["C12"].value = "=SUM(B2:B11)"

hoja["C15"].value = "Hoy es: "
hoja["D15"].value = datetime.datetime.now().strftime("%d/%m/%Y")

libro.save("listado.xlsx")
print("Libro creado exitosamente")
# Out:
# Libro creado exitosamente

# %%
libro = openpyxl.Workbook()

hoja = libro["Sheet"]

celda_A1 = hoja["A1"].value
celda_B1 = hoja["B1"].value

print(celda_A1)
print(celda_B1)
# Out:
# None
# None

# %%
valor_celda_B1_cordenadas= hoja.cell(row=1, column=2).value
print(valor_celda_B1_cordenadas)

for renglon in range(1, 8):
  print(f"{renglon}, {hoja.cell(row=renglon, column= 2).value}")
# Out:
# None
# 1, None
# 2, None
# 3, None
# 4, None
# 5, None
# 6, None
# 7, None

# %%
range_celda = hoja["A1":"C7"]
for renglon in range_celda:
  for celda in renglon:
    print(f"Celda: {celda.coordinate} = {celda.value}")
  print("---Fin del renglon---")
# Out:
# Celda: A1 = None
# Celda: B1 = None
# Celda: C1 = None
# ---Fin del renglon---
# Celda: A2 = None
# Celda: B2 = None
# Celda: C2 = None
# ---Fin del renglon---
# Celda: A3 = None
# Celda: B3 = None
# Celda: C3 = None
# ---Fin del renglon---
# Celda: A4 = None
# Celda: B4 = None
# Celda: C4 = None
# ---Fin del renglon---
# Celda: A5 = None
# Celda: B5 = None
# Celda: C5 = None
# ---Fin del renglon---
# Celda: A6 = None
# Celda: B6 = None
# Celda: C6 = None
# ---Fin del renglon---
# Celda: A7 = None
# Celda: B7 = None
# Celda: C7 = None
# ---Fin del renglon---
