# %%
diccionario_vacio = {}
diccionario_citas = {"T'Challa":"Wakanda Forever",
                     "Thanos":"The hardest choices require the strongest wills",
                     "AMLO":"Me canso ganso"}

print(diccionario_citas)
# Out:
# {"T'Challa": 'Wakanda Forever', 'Thanos': 'The hardest choices require the strongest wills', 'AMLO': 'Me canso ganso'}

# %%
print(diccionario_citas["Thanos"])
# Out:
# The hardest choices require the strongest wills

# %%
diccionario_citas["Plankton"] = "¡Por fin tengo la fórmula de la cangreburger!"
print(diccionario_citas)
# Out:
# {"T'Challa": 'Wakanda Forever', 'Thanos': 'The hardest choices require the strongest wills', 'AMLO': 'Me canso ganso', 'Plankton': '¡Por fin tengo la fórmula de la cangreburger!'}

# %%
del diccionario_citas["AMLO"]
print(diccionario_citas)
# Out:
# {"T'Challa": 'Wakanda Forever', 'Thanos': 'The hardest choices require the strongest wills', 'Plankton': '¡Por fin tengo la fórmula de la cangreburger!'}

# %%
#Opción 1 : Todas las claves, solamente las claves
print(list(diccionario_citas.keys()))

#Opción 2 : Todos los valores, solamente los valores
print(list(diccionario_citas.values()))

#Opción 3 : Todos los elementos, elemento por elemento
print(list(diccionario_citas.items()))
# Out:
# ["T'Challa", 'Thanos', 'Plankton']
# ['Wakanda Forever', 'The hardest choices require the strongest wills', '¡Por fin tengo la fórmula de la cangreburger!']
# [("T'Challa", 'Wakanda Forever'), ('Thanos', 'The hardest choices require the strongest wills'), ('Plankton', '¡Por fin tengo la fórmula de la cangreburger!')]

# %%
print(dict([['pedro', 23], ['Juan', 10]]))
# Out:
# {'pedro': 23, 'Juan': 10}

# %%
diccionario_citas = {"T'Challa":"Wakanda Forever",
                     "Thanos":"The hardest choices require the strongest wills",
                     "AMLO":"Me canso ganso"}
diccionario_citas["Plankton"] = "¡Por fin tengo la fórmula de la cangreburger!"
print(diccionario_citas.get("Plankton"))
# Out:
# ¡Por fin tengo la fórmula de la cangreburger!

# %%
del diccionario_citas["Plankton"]
print(diccionario_citas)
# Out:
# {"T'Challa": 'Wakanda Forever', 'Thanos': 'The hardest choices require the strongest wills', 'AMLO': 'Me canso ganso'}
