# %%
t = (1, 2, 3)
t
# Out:
# (1, 2, 3)

# %%
t = (1, "FCB", 3.2)
t
# Out:
# (1, 'FCB', 3.2)

# %%
t = ()
t
# Out:
# ()

# %%
(1, )
# Out:
# (1,)

# %%
valores = ("Python", True, "Zope", 5)
print("True->", valores.count(True))
print("Zope->", valores.count("Zope"))
print("5->", valores.count(5))
# Out:
# True-> 1
# Zope-> 1
# 5-> 1

# %%
valores = ("Python", True, "Zope", 5)
print(valores.index("Zope"))
print(valores.index(True))
print(valores.index(5))
# Out:
# 2
# 1
# 3
