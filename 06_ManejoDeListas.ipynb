# %%
#Lista vacia
()
# Out:
# ()

# %%
#Lista con elementos 1,2,3
(1, 2, 3)
# Out:
# (1, 2, 3)

# %%
#Lista con diferentes objetos
("Python", 2.3, 45)
# Out:
# ('Python', 2.3, 45)

# %%
print(list("Python"))
# Out:
# ['P', 'y', 't', 'h', 'o', 'n']

# %%
factura = ['pan', 'huevos', 100, 1234]
factura
# Out:
# ['pan', 'huevos', 100, 1234]

# %%
factura[0]
# Out:
# 'pan'

# %%
factura[3]
# Out:
# 1234

# %%
len(factura)
# Out:
# 4

# %%
len(factura) - 1
# Out:
# 3

# %%
factura[1] = 'carne'
factura
# Out:
# ['pan', 'carne', 100, 1234]

# %%
versiones_iphone = [2.5, 3.6, 4, 5]
print(versiones_iphone)
# Out:
# [2.5, 3.6, 4, 5]

# %%
versiones_iphone.append(6)
print(versiones_iphone)
# Out:
# [2.5, 3.6, 4, 5, 6]

# %%
lista =[1, 2, 3, 4, 5]
lista.append(6)
print(lista)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
versiones_iphone = [2.1, 2.5, 3.6]
print(versiones_iphone)
# Out:
# [2.1, 2.5, 3.6]

# %%
versiones_iphone.extend([4])
print(versiones_iphone)
# Out:
# [2.1, 2.5, 3.6, 4]

# %%
versiones_iphone = [2.1, 2.5, 3.6, 4, 5, 6]
print(versiones_iphone)
# Out:
# [2.1, 2.5, 3.6, 4, 5, 6]

# %%
versiones_iphone.insert(2, 3.7)
print(versiones_iphone)
# Out:
# [2.1, 2.5, 3.7, 3.6, 4, 5, 6]

# %%
versiones_iphone = [2.1, 2.5, 3.6, 4, 5, 6]
versiones_iphone
# Out:
# [2.1, 2.5, 3.6, 4, 5, 6]

# %%
versiones_iphone.count(4)
# Out:
# 1

# %%
versiones_iphone = [2.1, 2.5, 3.6, 4, 5, 6]
print(versiones_iphone.pop())
# Out:
# 6

# %%
versiones_iphone = [2.1, 2.5, 3.6, 4, 5, 6]
print(versiones_iphone.pop(2))
# Out:
# 3.6

# %%
versiones_iphone = [2.1, 2.5, 3.6, 4, 5, 6]
versiones_iphone.remove(2.5)
print(versiones_iphone)
# Out:
# [2.1, 3.6, 4, 5, 6]

# %%
versiones_iphone = [2.1, 2.5, 3.6, 4, 5, 6]
versiones_iphone.reverse()
print(versiones_iphone)
# Out:
# [6, 5, 4, 3.6, 2.5, 2.1]

# %%
versiones_iphone = [2.1, 2.5, 3.6, 4, 5, 6]
versiones_iphone.sort()
print(versiones_iphone)
# Out:
# [2.1, 2.5, 3.6, 4, 5, 6]

# %%
versiones_iphone = [2.1, 2.5, 3.6, 4, 5, 6]
versiones_iphone.sort(reverse=True)
print(versiones_iphone)
# Out:
# [6, 5, 4, 3.6, 2.5, 2.1]
